# %% [markdown]
# <a href="https://colab.research.google.com/github/CSSrihari/hari/blob/main/LLM_Openrouter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://openrouter.ai/settings/keys

# %%
# !pip install langchain_community -q

# %%
# !pip install langchain-experimental -q

# %%
# !pip install pdfplumber -q

# %%
# !pip install faiss-cpu -q

# %%
# !git clone https://github.com/deepanrajm/deep_learning.git
# Out:
# fatal: destination path 'deep_learning' already exists and is not an empty directory.

# %%
# !pip install langchain-openai -q

# %%
import os
from langchain_openai import ChatOpenAI # Updated import
from langchain_core.messages import HumanMessage

# Step 1: Set your OpenRouter API key and endpoint
os.environ["OPENAI_API_KEY"] = "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"  # Replace with your actual OpenRouter API key
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# Step 2: Initialize the LLM
llm = ChatOpenAI(
    model="upstage/solar-pro-3:free",  # or try "meta-llama/llama-3-8b-instruct", etc.
    temperature=0.7,
    openai_api_base=os.environ["OPENAI_API_BASE"],
    openai_api_key=os.environ["OPENAI_API_KEY"],
    request_timeout=60,
    verbose=True
)

# Step 3: Interact with the model (normal chat mode)
while True:
    query = input("\nYou: ")
    if query.lower() in ["exit", "quit", "bye"]:
        print("Goodbye!")
        break

    response = llm.invoke([HumanMessage(content=query)]) # Corrected method call
    print("\nAssistant:", response.content)
# Out:
# You: home remedy for cold
#
# Assistant: **Home‑remedy ideas for a common cold**
# *(These are general suggestions. If your symptoms are severe, last more than a week, or you have underlying health conditions, please see a healthcare professional.)*
#
# ---
#
# ### 1. Stay well‑hydrated
# | Why it helps | How to do it |
# |--------------|--------------|
# | Fluids thin mucus, keep the throat moist, and help the body flush out viruses. | • Warm water, herbal teas, clear broths, or diluted fruit juices. <br>• Aim for at least 8–10 cups (2–2.5 L) of fluid per day. |
#
# ---
#
# ### 2. Warm, soothing liquids
# | Remedy | Evidence & notes |
# |--------|------------------|
# | **Honey** (1 tsp in warm water or tea) | Can coat the throat, reduce cough frequency, and has mild antimicrobial properties. **Only give honey to children older than 1 year** (infants risk botulism). |
# | **Ginger tea** (fresh ginger sliced, steeped in hot water) | Ginger contains compounds (gingerol) that may reduce inflammation and help clear congestion. |
# | **Peppermint or eucalyptus tea** | The menthol sensation can relieve nasal blockage temporarily. Use a few drops of essential oil in a diffuser *or* a steam inhalation (see below). |
# | **Chicken soup** | Warm broth provides hydration and electrolytes; studies suggest it may have mild anti‑inflammatory effects and help loosen mucus. |
#
# ---
#
# ### 3. Steam inhalation & humidification
# | Method | How to do it |
# |--------|--------------|
# | **Hot shower or bowl of hot water** (add a few drops of eucalyptus or peppermint oil if you like) | Inhale the steam for 5‑10 minutes, covering your head with a towel to trap moisture. |
# | **Humidifier** (cool‑mist) | Keeps indoor air moist, especially helpful at night when nasal passages can dry out. Clean the device daily to prevent mold growth. |
#
# ---
#
# ### 4. Salt‑water nasal rinse (neti pot or squeeze bottle)
# | Why it works | Steps |
# |--------------|-------|
# | Flushes out viral particles, reduces congestion, and can thin mucus. | 1. Mix ¼ tsp non‑iodized salt + ¼ tsp baking soda in 8 oz distilled or boiled‑cooled water. <br>2. Lean over a sink, tilt head sideways, pour gently through one nostril, let it drain out the other. <br>3. Use once or twice daily; rinse the device with clean water after each use. |
#
# ---
#
# ### 5. Rest & sleep
# - Aim for 7‑9 hours of sleep (or more if you feel extremely fatigued).
# - Elevate your head with an extra pillow to reduce post‑nasal drip and improve breathing.
#
# ---
#
# ### 6. Nutrition & supplements (use with caution)
# | Item | Typical dose | What it may help |
# |------|--------------|-----------------|
# | **Vitamin C** (e.g., 500 mg daily) | May shorten cold duration by ~1 day, especially if taken early. |
# | **Zinc lozenges** (10‑15 mg elemental zinc) | Some studies show reduced symptom severity if started within 24 hours of onset. |
# | **Probiotics** (e.g., Lactobacillus rhamnosus) | May support immune function; evidence is modest. |
# | **Garlic** (raw cloves or supplement) | Contains allicin, a natural antimicrobial; may modestly lower risk of catching a cold. |
#
# > **Safety tip:** Check with your doctor before starting any supplement, especially if you’re pregnant, nursing, or take medications.
#
# ---
#
# ### 7. Other comfort measures
# | Remedy | How to apply |
# |--------|--------------|
# | **Warm compress** on the forehead or sinuses | Use a clean cloth soaked in warm water, applied for 5‑10 minutes. |
# | **Spicy foods** (e.g., chili peppers) | Capsaicin can stimulate nasal secretions, helping clear congestion. |
# | **Avoid irritants** – smoke, strong perfumes, alcohol | These can worsen throat irritation and congestion. |
# | **Gentle throat gargles** (warm salt water) | ½ tsp salt in 8 oz warm water; gargle for 15‑30 seconds, repeat 2‑3 times daily. |
#
# ---
#
# ### 8. When to seek medical care
# - Fever > 38.5 °C (101.3 °F) lasting > 3 days.
# - Severe headache, chest pain, shortness of breath, or wheezing.
# - Symptoms persisting > 10 days or getting worse after initial improvement.
# - Any underlying health condition (e.g., asthma, heart disease) that could be aggravated.
#
# ---
#
# #### Quick “starter” routine
# 1. **Morning:** Warm water with lemon + honey, a cup of ginger tea, and a neti‑pot rinse.
# 2. **Mid‑day:** Stay hydrated with herbal teas, add a pinch of ginger to soups.
# 3. **Evening:** Steam inhalation before bedtime, use a humidifier, and aim for 8‑9 hours of sleep.
# 4. **Optional:** If you’re comfortable, take a zinc lozenge early in the day and a vitamin C supplement (after checking with a pharmacist or doctor).
#
# ---
#
# **Disclaimer:** This information is for general educational purposes only and does not constitute medical advice. Always consult a qualified healthcare professional for personalized guidance, especially if you have chronic illnesses, are pregnant, or are taking prescription medications.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2895378635.py in <cell line: 0>()
#      19 # Step 3: Interact with the model (normal chat mode)
#      20 while True:
# ---> 21     query = input("\nYou: ")
#      22     if query.lower() in ["exit", "quit", "bye"]:
#      23         print("Goodbye!")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
pip install langchain-classic

# %%
import os
from langchain_openai  import ChatOpenAI
from langchain_classic.chains import RetrievalQA
from langchain_classic.chains.llm import LLMChain
from langchain_classic.chains.combine_documents.stuff import StuffDocumentsChain
from langchain_classic.prompts import PromptTemplate
from langchain_community.document_loaders import PDFPlumberLoader
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# Set your OpenRouter API key and endpoint
os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# Load and process PDF
loader = PDFPlumberLoader("/content/deep_learning/RAG/Basic_Home_Remedies.pdf")
docs = loader.load()
print("Pages loaded:", len(docs))

# Chunking
text_splitter = SemanticChunker(HuggingFaceEmbeddings())
documents = text_splitter.split_documents(docs)

# Vector DB
embedder = HuggingFaceEmbeddings()
vector = FAISS.from_documents(documents, embedder)
retriever = vector.as_retriever(search_type="similarity", search_kwargs={"k": 2})

# Use ChatOpenAI with OpenRouter backend
llm = ChatOpenAI(
    model="upstage/solar-pro-3:free",   #"mistralai/mistral-7b-instruct"
    temperature=0.7,
    openai_api_base="https://openrouter.ai/api/v1",
    openai_api_key=os.environ["OPENAI_API_KEY"],
    request_timeout=60,
)

# Prompt
prompt = """
You are a helpful assistant.
Use the following pieces of context to answer the question at the end.
Answer only using the context and be concise (3–4 sentences).

Context: {context}

Question: {question}

Answer:
"""
QA_CHAIN_PROMPT = PromptTemplate.from_template(prompt)

llm_chain = LLMChain(llm=llm, prompt=QA_CHAIN_PROMPT, verbose=True)

document_prompt = PromptTemplate(
    input_variables=["page_content", "source"],
    template="Context:\ncontent:{page_content}\nsource:{source}",
)

combine_documents_chain = StuffDocumentsChain(
    llm_chain=llm_chain,
    document_variable_name="context",
    document_prompt=document_prompt,
    callbacks=None,
)

qa = RetrievalQA(
    combine_documents_chain=combine_documents_chain,
    retriever=retriever,
    return_source_documents=True,
    verbose=True,
)

# Example query
result = qa("What is a natural remedy for cough mentioned in the document?")
print("Answer:", result["result"])
